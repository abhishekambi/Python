# %%
import pandas as pd
df = pd.read_excel(r"C:\Users\Abhishek\Desktop\Python\myworkbook.xlsx")
df
# Out:
#      mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0   21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4
# 1   21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# 2   22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1
# 3   21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1
# 4   18.7    8  360.0  175  3.15  3.440  17.02   0   0     3     2
# 5   18.1    6  225.0  105  2.76  3.460  20.22   1   0     3     1
# 6   14.3    8  360.0  245  3.21  3.570  15.84   0   0     3     4
# 7   24.4    4  146.7   62  3.69  3.190  20.00   1   0     4     2
# 8   22.8    4  140.8   95  3.92  3.150  22.90   1   0     4     2
# 9   19.2    6  167.6  123  3.92  3.440  18.30   1   0     4     4
# 10  17.8    6  167.6  123  3.92  3.440  18.90   1   0     4     4
# 11  16.4    8  275.8  180  3.07  4.070  17.40   0   0     3     3
# 12  17.3    8  275.8  180  3.07  3.730  17.60   0   0     3     3
# ...

# %%
df.columns   # dataset.function
# Out:
# Index(['mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am', 'gear',
#        'carb'],
#       dtype='object')

# %%
df.head()  # top 5 row
# Out:
#     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4
# 1  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# 2  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1
# 3  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1
# 4  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3     2

# %%
df.tail(3)   # bottom 3 row
# Out:
#      mpg  cyl   disp   hp  drat    wt  qsec  vs  am  gear  carb
# 29  19.7    6  145.0  175  3.62  2.77  15.5   0   1     5     6
# 30  15.0    8  301.0  335  3.54  3.57  14.6   0   1     5     8
# 31  21.4    4  121.0  109  4.11  2.78  18.6   1   1     4     2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   mpg     32 non-null     float64
#  1   cyl     32 non-null     int64
#  2   disp    32 non-null     float64
#  3   hp      32 non-null     int64
#  4   drat    32 non-null     float64
#  5   wt      32 non-null     float64
#  6   qsec    32 non-null     float64
#  7   vs      32 non-null     int64
#  8   am      32 non-null     int64
#  9   gear    32 non-null     int64
#  10  carb    32 non-null     int64
# dtypes: float64(5), int64(6)
# memory usage: 2.9 KB

# %% [markdown]
# #  Summary of just indexing operator
# * Its primary purpose is to select columns by the column names
# * Select a single column as a Series by passing the column name directly to it: df['col_name']
# * Select multiple columns as a DataFrame by passing a list to it: df[]

# %%
df.head()
# Out:
#     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4
# 1  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# 2  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1
# 3  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1
# 4  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3     2

# %%
df['mpg']   # by default it work for columns
# Out:
# 0     21.0
# 1     21.0
# 2     22.8
# 3     21.4
# 4     18.7
# 5     18.1
# 6     14.3
# 7     24.4
# 8     22.8
# 9     19.2
# 10    17.8
# 11    16.4
# 12    17.3
# 13    15.2
# 14    10.4
# 15    10.4
# 16    14.7
# 17    32.4
# 18    30.4
# 19    33.9
# 20    21.5
# 21    15.5
# 22    15.2
# 23    13.3
# 24    19.2
# 25    27.3
# 26    26.0
# 27    30.4
# 28    15.8
# 29    19.7
# 30    15.0
# 31    21.4
# Name: mpg, dtype: float64

# %%
df[['mpg']]    # to get column names
# Out:
#      mpg
# 0   21.0
# 1   21.0
# 2   22.8
# 3   21.4
# 4   18.7
# 5   18.1
# 6   14.3
# 7   24.4
# 8   22.8
# 9   19.2
# 10  17.8
# 11  16.4
# 12  17.3
# 13  15.2
# 14  10.4
# 15  10.4
# 16  14.7
# 17  32.4
# 18  30.4
# 19  33.9
# 20  21.5
# 21  15.5
# 22  15.2
# 23  13.3
# 24  19.2
# 25  27.3
# 26  26.0
# 27  30.4
# 28  15.8
# 29  19.7
# 30  15.0
# 31  21.4

# %%
df[['mpg', 'cyl', 'hp']]
# Out:
#      mpg  cyl   hp
# 0   21.0    6  110
# 1   21.0    6  110
# 2   22.8    4   93
# 3   21.4    6  110
# 4   18.7    8  175
# 5   18.1    6  105
# 6   14.3    8  245
# 7   24.4    4   62
# 8   22.8    4   95
# 9   19.2    6  123
# 10  17.8    6  123
# 11  16.4    8  180
# 12  17.3    8  180
# 13  15.2    8  180
# 14  10.4    8  205
# 15  10.4    8  215
# 16  14.7    8  230
# 17  32.4    4   66
# 18  30.4    4   52
# 19  33.9    4   65
# 20  21.5    4   97
# 21  15.5    8  150
# 22  15.2    8  150
# 23  13.3    8  245
# 24  19.2    8  175
# 25  27.3    4   66
# 26  26.0    4   91
# 27  30.4    4  113
# 28  15.8    8  264
# 29  19.7    6  175
# 30  15.0    8  335
# 31  21.4    4  109

# %% [markdown]
# #  Getting started with .loc
# The .loc indexer selects data in a different way than just the indexing operator. It can select subsets of rows or columns. It can a subsets of rwos and columns. Most importantly, it only selects data by the LABEL of the rwos and columns.

# %%
df.head()   # top 5 row
# Out:
#     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4
# 1  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# 2  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1
# 3  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1
# 4  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3     2

# %%
df.loc[4,:]   # 1 rwo and : all data
# Out:
# mpg      18.70
# cyl       8.00
# disp    360.00
# hp      175.00
# drat      3.15
# wt        3.44
# qsec     17.02
# vs        0.00
# am        0.00
# gear      3.00
# carb      2.00
# Name: 4, dtype: float64

# %% [markdown]
# Select numtiple rows as a dataframe with

# %%
df.loc[3,:]   # select 0 to 5 row and all columns
# Out:
# mpg      21.400
# cyl       6.000
# disp    258.000
# hp      110.000
# drat      3.080
# wt        3.215
# qsec     19.440
# vs        1.000
# am        0.000
# gear      3.000
# carb      1.000
# Name: 3, dtype: float64

# %% [markdown]
# Use slice notation to select a range of rows with .loc

# %%
df.loc[0:3]   # without, by default take row
# Out:
#     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4
# 1  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# 2  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1
# 3  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1

# %% [markdown]
# #  Column Subset

# %%
df.loc[:,'mpg']   # for one column without header
# Out:
# 0     21.0
# 1     21.0
# 2     22.8
# 3     21.4
# 4     18.7
# 5     18.1
# 6     14.3
# 7     24.4
# 8     22.8
# 9     19.2
# 10    17.8
# 11    16.4
# 12    17.3
# 13    15.2
# 14    10.4
# 15    10.4
# 16    14.7
# 17    32.4
# 18    30.4
# 19    33.9
# 20    21.5
# 21    15.5
# 22    15.2
# 23    13.3
# 24    19.2
# 25    27.3
# 26    26.0
# 27    30.4
# 28    15.8
# 29    19.7
# 30    15.0
# 31    21.4
# Name: mpg, dtype: float64

# %%
df.loc[:,['mpg']]   #with header ['mpg']
# Out:
#      mpg
# 0   21.0
# 1   21.0
# 2   22.8
# 3   21.4
# 4   18.7
# 5   18.1
# 6   14.3
# 7   24.4
# 8   22.8
# 9   19.2
# 10  17.8
# 11  16.4
# 12  17.3
# 13  15.2
# 14  10.4
# 15  10.4
# 16  14.7
# 17  32.4
# 18  30.4
# 19  33.9
# 20  21.5
# 21  15.5
# 22  15.2
# 23  13.3
# 24  19.2
# 25  27.3
# 26  26.0
# 27  30.4
# 28  15.8
# 29  19.7
# 30  15.0
# 31  21.4

# %%
df.columns
# Out:
# Index(['mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am', 'gear',
#        'carb'],
#       dtype='object')

# %%
df.loc[:,['mpg', 'hp', 'cyl']]   # for more than one column
# Out:
#      mpg   hp  cyl
# 0   21.0  110    6
# 1   21.0  110    6
# 2   22.8   93    4
# 3   21.4  110    6
# 4   18.7  175    8
# 5   18.1  105    6
# 6   14.3  245    8
# 7   24.4   62    4
# 8   22.8   95    4
# 9   19.2  123    6
# 10  17.8  123    6
# 11  16.4  180    8
# 12  17.3  180    8
# 13  15.2  180    8
# 14  10.4  205    8
# 15  10.4  215    8
# 16  14.7  230    8
# 17  32.4   66    4
# 18  30.4   52    4
# 19  33.9   65    4
# 20  21.5   97    4
# 21  15.5  150    8
# 22  15.2  150    8
# 23  13.3  245    8
# 24  19.2  175    8
# 25  27.3   66    4
# 26  26.0   91    4
# 27  30.4  113    4
# 28  15.8  264    8
# 29  19.7  175    6
# 30  15.0  335    8
# 31  21.4  109    4

# %% [markdown]
# # Combining =  Column & Row Subset

# %%
df.head()
# Out:
#     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4
# 1  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# 2  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1
# 3  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1
# 4  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3     2

# %%
df.loc[0:2,['mpg','cyl','hp']]
# Out:
#     mpg  cyl   hp
# 0  21.0    6  110
# 1  21.0    6  110
# 2  22.8    4   93

# %%
df.loc[0:5,['mpg','hp','wt']]
# Out:
#     mpg   hp     wt
# 0  21.0  110  2.620
# 1  21.0  110  2.875
# 2  22.8   93  2.320
# 3  21.4  110  3.215
# 4  18.7  175  3.440
# 5  18.1  105  3.460

# %%
df.loc[0:4, "mpg":"hp"]
# Out:
#     mpg  cyl   disp   hp
# 0  21.0    6  160.0  110
# 1  21.0    6  160.0  110
# 2  22.8    4  108.0   93
# 3  21.4    6  258.0  110
# 4  18.7    8  360.0  175

# %%
df.loc[[1,3,6,9],['wt', 'vs','am']]
# Out:
#       wt  vs  am
# 1  2.875   0   1
# 3  3.215   1   0
# 6  3.570   0   0
# 9  3.440   1   0

# %%
df.loc[[1,5,10],["mpg","disp","am"]]
# Out:
#      mpg   disp  am
# 1   21.0  160.0   1
# 5   18.1  225.0   0
# 10  17.8  167.6   0

# %%
df.loc[1:5 , "hp":"am"]
# Out:
#     hp  drat     wt   qsec  vs  am
# 1  110  3.90  2.875  17.02   0   1
# 2   93  3.85  2.320  18.61   1   1
# 3  110  3.08  3.215  19.44   1   0
# 4  175  3.15  3.440  17.02   0   0
# 5  105  2.76  3.460  20.22   1   0

# %%
df.loc[[5,10,15,20],["hp","wt","am"]]
# Out:
#      hp     wt  am
# 5   105  3.460   0
# 10  123  3.440   0
# 15  215  5.424   0
# 20   97  2.465   0

# %% [markdown]
# df.loc[(df.category='Technology' df.sub_category='phones')]

# %%
df.loc[df.cyl == 6,:]
# Out:
#      mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0   21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4
# 1   21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# 3   21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1
# 5   18.1    6  225.0  105  2.76  3.460  20.22   1   0     3     1
# 9   19.2    6  167.6  123  3.92  3.440  18.30   1   0     4     4
# 10  17.8    6  167.6  123  3.92  3.440  18.90   1   0     4     4
# 29  19.7    6  145.0  175  3.62  2.770  15.50   0   1     5     6

# %%
df.loc[df.cyl > 0,:]
# Out:
#      mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0   21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4
# 1   21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# 2   22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1
# 3   21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1
# 4   18.7    8  360.0  175  3.15  3.440  17.02   0   0     3     2
# 5   18.1    6  225.0  105  2.76  3.460  20.22   1   0     3     1
# 6   14.3    8  360.0  245  3.21  3.570  15.84   0   0     3     4
# 7   24.4    4  146.7   62  3.69  3.190  20.00   1   0     4     2
# 8   22.8    4  140.8   95  3.92  3.150  22.90   1   0     4     2
# 9   19.2    6  167.6  123  3.92  3.440  18.30   1   0     4     4
# 10  17.8    6  167.6  123  3.92  3.440  18.90   1   0     4     4
# 11  16.4    8  275.8  180  3.07  4.070  17.40   0   0     3     3
# 12  17.3    8  275.8  180  3.07  3.730  17.60   0   0     3     3
# ...

# %%
df
# Out:
#      mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0   21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4
# 1   21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# 2   22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1
# 3   21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1
# 4   18.7    8  360.0  175  3.15  3.440  17.02   0   0     3     2
# 5   18.1    6  225.0  105  2.76  3.460  20.22   1   0     3     1
# 6   14.3    8  360.0  245  3.21  3.570  15.84   0   0     3     4
# 7   24.4    4  146.7   62  3.69  3.190  20.00   1   0     4     2
# 8   22.8    4  140.8   95  3.92  3.150  22.90   1   0     4     2
# 9   19.2    6  167.6  123  3.92  3.440  18.30   1   0     4     4
# 10  17.8    6  167.6  123  3.92  3.440  18.90   1   0     4     4
# 11  16.4    8  275.8  180  3.07  4.070  17.40   0   0     3     3
# 12  17.3    8  275.8  180  3.07  3.730  17.60   0   0     3     3
# ...

# %%
df.loc[df.cyl==6,["mpg","cyl",'disp']]
# Out:
#      mpg  cyl   disp
# 0   21.0    6  160.0
# 1   21.0    6  160.0
# 3   21.4    6  258.0
# 5   18.1    6  225.0
# 9   19.2    6  167.6
# 10  17.8    6  167.6
# 29  19.7    6  145.0

# %% [markdown]
# # Changing Data type

# %%
df
# Out:
#      mpg cyl   disp   hp  drat     wt   qsec vs am  gear  carb
# 0   21.0   6  160.0  110  3.90  2.620  16.46  0  1     4     4
# 1   21.0   6  160.0  110  3.90  2.875  17.02  0  1     4     4
# 2   22.8   4  108.0   93  3.85  2.320  18.61  1  1     4     1
# 3   21.4   6  258.0  110  3.08  3.215  19.44  1  0     3     1
# 4   18.7   8  360.0  175  3.15  3.440  17.02  0  0     3     2
# 5   18.1   6  225.0  105  2.76  3.460  20.22  1  0     3     1
# 6   14.3   8  360.0  245  3.21  3.570  15.84  0  0     3     4
# 7   24.4   4  146.7   62  3.69  3.190  20.00  1  0     4     2
# 8   22.8   4  140.8   95  3.92  3.150  22.90  1  0     4     2
# 9   19.2   6  167.6  123  3.92  3.440  18.30  1  0     4     4
# 10  17.8   6  167.6  123  3.92  3.440  18.90  1  0     4     4
# 11  16.4   8  275.8  180  3.07  4.070  17.40  0  0     3     3
# 12  17.3   8  275.8  180  3.07  3.730  17.60  0  0     3     3
# 13  15.2   8  275.8  180  3.07  3.780  18.00  0  0     3     3
# ...

# %%
df.info()   # data structure
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   mpg     32 non-null     float64
#  1   cyl     32 non-null     object
#  2   disp    32 non-null     float64
#  3   hp      32 non-null     int64
#  4   drat    32 non-null     float64
#  5   wt      32 non-null     float64
#  6   qsec    32 non-null     float64
#  7   vs      32 non-null     object
#  8   am      32 non-null     object
#  9   gear    32 non-null     int64
#  10  carb    32 non-null     int64
# dtypes: float64(5), int64(3), object(3)
# memory usage: 2.9+ KB

# %%
df.cyl=df.cyl.astype(str)
# str  # converting data type of 1 column

# %%
convert_dict = {'vs': str, 'am': str}
#converting dta type of more than 1 column
df = df.astype(convert_dict)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   mpg     32 non-null     float64
#  1   cyl     32 non-null     object
#  2   disp    32 non-null     float64
#  3   hp      32 non-null     int64
#  4   drat    32 non-null     float64
#  5   wt      32 non-null     float64
#  6   qsec    32 non-null     float64
#  7   vs      32 non-null     object
#  8   am      32 non-null     object
#  9   gear    32 non-null     int64
#  10  carb    32 non-null     int64
# dtypes: float64(5), int64(3), object(3)
# memory usage: 2.9+ KB

# %%
df.head()
# Out:
#     mpg cyl   disp   hp  drat     wt   qsec vs am  gear  carb
# 0  21.0   6  160.0  110  3.90  2.620  16.46  0  1     4     4
# 1  21.0   6  160.0  110  3.90  2.875  17.02  0  1     4     4
# 2  22.8   4  108.0   93  3.85  2.320  18.61  1  1     4     1
# 3  21.4   6  258.0  110  3.08  3.215  19.44  1  0     3     1
# 4  18.7   8  360.0  175  3.15  3.440  17.02  0  0     3     2

# %%
df.cyl.value_counts()
# Out:
# 8    14
# 4    11
# 6     7
# Name: cyl, dtype: int64

# %%
a = df.loc[df.cyl=='6',:]   # conditional subset

# %%
a
# Out:
#      mpg cyl   disp   hp  drat     wt   qsec vs am  gear  carb
# 0   21.0   6  160.0  110  3.90  2.620  16.46  0  1     4     4
# 1   21.0   6  160.0  110  3.90  2.875  17.02  0  1     4     4
# 3   21.4   6  258.0  110  3.08  3.215  19.44  1  0     3     1
# 5   18.1   6  225.0  105  2.76  3.460  20.22  1  0     3     1
# 9   19.2   6  167.6  123  3.92  3.440  18.30  1  0     4     4
# 10  17.8   6  167.6  123  3.92  3.440  18.90  1  0     4     4
# 29  19.7   6  145.0  175  3.62  2.770  15.50  0  1     5     6

# %%
df.loc[df.cyl=='6','mpg':'hp']   # conditional subset by by row n columns
# Out:
#      mpg cyl   disp   hp
# 0   21.0   6  160.0  110
# 1   21.0   6  160.0  110
# 3   21.4   6  258.0  110
# 5   18.1   6  225.0  105
# 9   19.2   6  167.6  123
# 10  17.8   6  167.6  123
# 29  19.7   6  145.0  175

# %% [markdown]
# # Column Deletion
# * One column at a time
# * More column at a time

# %%
df.columns
# Out:
# Index(['mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am', 'gear',
#        'carb'],
#       dtype='object')

# %%
df.head(3)
# Out:
#     mpg cyl   disp   hp  drat     wt   qsec vs am  gear  carb
# 0  21.0   6  160.0  110  3.90  2.620  16.46  0  1     4     4
# 1  21.0   6  160.0  110  3.90  2.875  17.02  0  1     4     4
# 2  22.8   4  108.0   93  3.85  2.320  18.61  1  1     4     1

# %%
df = df.head(3).drop('cyl',axis=1)   # axis = 1 means column index

df.head()
# Out:
#     mpg   disp   hp  drat     wt   qsec vs am  gear  carb
# 0  21.0  160.0  110  3.90  2.620  16.46  0  1     4     4
# 1  21.0  160.0  110  3.90  2.875  17.02  0  1     4     4
# 2  22.8  108.0   93  3.85  2.320  18.61  1  1     4     1

# %%
df= df.head().drop(['wt','hp','vs'], axis=1)   #axis = 1 means column index
df.head()
# Out:
#     mpg   disp  drat   qsec am  gear  carb
# 0  21.0  160.0  3.90  16.46  1     4     4
# 1  21.0  160.0  3.90  17.02  1     4     4
# 2  22.8  108.0  3.85  18.61  1     4     1

# %%
df= df.head().drop(1,axis=0)   # axis = 1 means column index

df
# Out:
#     mpg   disp  drat   qsec am  gear  carb
# 0  21.0  160.0  3.90  16.46  1     4     4
# 2  22.8  108.0  3.85  18.61  1     4     1

# %%
df= df.drop(1,axis=0)   # axis = 1 means column index

df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [66], in <cell line: 1>()
# ----> 1 df= df.drop(1,axis=0)   # axis = 1 means column index
#       3 df
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
#    4815     errors: str = "raise",
# ...

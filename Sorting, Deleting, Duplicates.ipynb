# %% [markdown]
# # Agenda
# * Sort Data
# * Deleting Column
# * Find the duplicate rows
# * Delete or drop rows

# %% [markdown]
# #  Sort a DataFrame in Python pandas
# * Sort the python pandas DataFrame by single column - Ascending & Descending order
# * Sort the pandas DataFrame by Multiple Columns
# * by index

# %%
import pandas as pd
import numpy as np

# Create a Dictionary of series
d = {'Name': ['Alisa',  'Bobby', 'Cathrine', 'Madonna',
             'Rocky', 'Sebasian', 'Jaqluine', 'Rahul',
             'David', 'Andrew', 'Ajay','Teresa'],
     'Age': [36,27,25,24,31,27,25,33,42,32,51,47],
     'Score': [89,87,67,55,47,72,76,79,44,92,99,92]}

# Create a DataFrame
df = pd.DataFrame(d)
df
# Out:
#         Name  Age  Score
# 0      Alisa   36     89
# 1      Bobby   27     87
# 2   Cathrine   25     67
# 3    Madonna   24     55
# 4      Rocky   31     47
# 5   Sebasian   27     72
# 6   Jaqluine   25     76
# 7      Rahul   33     79
# 8      David   42     44
# 9     Andrew   32     92
# 10      Ajay   51     99
# 11    Teresa   47     92

# %% [markdown]
# #  Sort the Python pandas DataFrame by Single Column -

# %%
df.sort_values(by='Score')
# Out:
#         Name  Age  Score
# 8      David   42     44
# 4      Rocky   31     47
# 3    Madonna   24     55
# 2   Cathrine   25     67
# 5   Sebasian   27     72
# 6   Jaqluine   25     76
# 7      Rahul   33     79
# 1      Bobby   27     87
# 0      Alisa   36     89
# 9     Andrew   32     92
# 11    Teresa   47     92
# 10      Ajay   51     99

# %% [markdown]
# # Descending order

# %%
# sort the pandas dataframe by descending value of
# single column

df.sort_values(by='Score', ascending=False)  # ascending false means descending
# Out:
#         Name  Age  Score
# 10      Ajay   51     99
# 9     Andrew   32     92
# 11    Teresa   47     92
# 0      Alisa   36     89
# 1      Bobby   27     87
# 7      Rahul   33     79
# 6   Jaqluine   25     76
# 5   Sebasian   27     72
# 2   Cathrine   25     67
# 3    Madonna   24     55
# 4      Rocky   31     47
# 8      David   42     44

# %% [markdown]
# #  Sort the pandas DataFrame by index Columns

# %%
# # sort the pandas dataframe by index ascending
df1=df.sort_index()
df1
# Out:
#         Name  Age  Score
# 0      Alisa   36     89
# 1      Bobby   27     87
# 2   Cathrine   25     67
# 3    Madonna   24     55
# 4      Rocky   31     47
# 5   Sebasian   27     72
# 6   Jaqluine   25     76
# 7      Rahul   33     79
# 8      David   42     44
# 9     Andrew   32     92
# 10      Ajay   51     99
# 11    Teresa   47     92

# %%
# sort the pandas dataframe by index descending

df2 = df.sort_index(ascending=False)
df2
# Out:
#         Name  Age  Score
# 11    Teresa   47     92
# 10      Ajay   51     99
# 9     Andrew   32     92
# 8      David   42     44
# 7      Rahul   33     79
# 6   Jaqluine   25     76
# 5   Sebasian   27     72
# 4      Rocky   31     47
# 3    Madonna   24     55
# 2   Cathrine   25     67
# 1      Bobby   27     87
# 0      Alisa   36     89

# %% [markdown]
# #  Deleting
# * axis = 1 denotes column
# * axis = 0 denotes row

# %% [markdown]
# # Drop

# %%
df.head()
# Out:
#        Name  Age  Score
# 0     Alisa   36     89
# 1     Bobby   27     87
# 2  Cathrine   25     67
# 3   Madonna   24     55
# 4     Rocky   31     47

# %%
# drop a column based on a name

df.drop('Age', axis=1)   # axis = 1 denotes column
# Out:
#         Name  Score
# 0      Alisa     89
# 1      Bobby     87
# 2   Cathrine     67
# 3    Madonna     55
# 4      Rocky     47
# 5   Sebasian     72
# 6   Jaqluine     76
# 7      Rahul     79
# 8      David     44
# 9     Andrew     92
# 10      Ajay     99
# 11    Teresa     92

# %%
df.head()
# Out:
#        Name  Age  Score
# 0     Alisa   36     89
# 1     Bobby   27     87
# 2  Cathrine   25     67
# 3   Madonna   24     55
# 4     Rocky   31     47

# %%
# drop Multiple column based on name
df.drop(['Age', 'Score'], axis=1)   # axis = 1 denotes column
# Out:
#         Name
# 0      Alisa
# 1      Bobby
# 2   Cathrine
# 3    Madonna
# 4      Rocky
# 5   Sebasian
# 6   Jaqluine
# 7      Rahul
# 8      David
# 9     Andrew
# 10      Ajay
# 11    Teresa

# %% [markdown]
# # Drop a column based on column index

# %%
df.head()
# Out:
#        Name  Age  Score
# 0     Alisa   36     89
# 1     Bobby   27     87
# 2  Cathrine   25     67
# 3   Madonna   24     55
# 4     Rocky   31     47

# %%
# drop a column based on column index

df.drop(df.columns[1], axis=1)
#index 2 is dropped (3rd column)
# Out:
#         Name  Score
# 0      Alisa     89
# 1      Bobby     87
# 2   Cathrine     67
# 3    Madonna     55
# 4      Rocky     47
# 5   Sebasian     72
# 6   Jaqluine     76
# 7      Rahul     79
# 8      David     44
# 9     Andrew     92
# 10      Ajay     99
# 11    Teresa     92

# %%
df.head()
# Out:
#        Name  Age  Score
# 0     Alisa   36     89
# 1     Bobby   27     87
# 2  Cathrine   25     67
# 3   Madonna   24     55
# 4     Rocky   31     47

# %%
df=df.drop(2,axis = 0)   # axis = 0 means row index
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [23], in <cell line: 1>()
# ----> 1 df=df.drop(2,axis = 1)   # axis = 0 means row index
#       2 df
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
#    4815     errors: str = "raise",
# ...

# %% [markdown]
# # Delete a column based on column name

# %%
del df['Age']
df
# Out:
#         Name  Score
# 0      Alisa     89
# 1      Bobby     87
# 3    Madonna     55
# 4      Rocky     47
# 5   Sebasian     72
# 6   Jaqluine     76
# 7      Rahul     79
# 8      David     44
# 9     Andrew     92
# 10      Ajay     99
# 11    Teresa     92

# %% [markdown]
# # Duplicate Row

# %%
# Create a DataFrame
d = {'Name': ['Alisa', 'Bobby', 'jodha', 'jack', 'raghu',
             'Cathrine', 'Alisa', 'Bobby', 'kumar', 'Alisa', 
             'Alex', 'Cathrine'],
    'Age': [36,24,23,22,23,24,26,24,22,23,24,24],
    'Score' : [85,63,55,74,31,77,85,63,42,62,89,77]}

df = pd.DataFrame(d)
df
# Out:
#         Name  Age  Score
# 0      Alisa   36     85
# 1      Bobby   24     63
# 2      jodha   23     55
# 3       jack   22     74
# 4      raghu   23     31
# 5   Cathrine   24     77
# 6      Alisa   26     85
# 7      Bobby   24     63
# 8      kumar   22     42
# 9      Alisa   23     62
# 10      Alex   24     89
# 11  Cathrine   24     77

# %% [markdown]
# #  Find the duplicate row in pandas

# %%
df["check_duplicate"]= df.duplicated()
df
# Out:
#         Name  Age  Score  check_duplicate
# 0      Alisa   36     85            False
# 1      Bobby   24     63            False
# 2      jodha   23     55            False
# 3       jack   22     74            False
# 4      raghu   23     31            False
# 5   Cathrine   24     77            False
# 6      Alisa   26     85            False
# 7      Bobby   24     63             True
# 8      kumar   22     42            False
# 9      Alisa   23     62            False
# 10      Alex   24     89            False
# 11  Cathrine   24     77             True

# %% [markdown]
# #  Drop the duplicate rows

# %%
import numpy as np

# Create a DataFrame
d = {
    'Name': ['Alisa', 'Bobby', 'jodha', 'jack', 'raghu','Cathrine',
              'Alisa', 'Bobby', 'kumar', 'Alisa','Alex', 'Cathrine'],
    'Age': [36,24,23,22,23,24,26,24,22,23,24,24],
    'Score' : [85,63,55,74,31,77,85,63,42,62,89,77]
    }

df = pd.DataFrame(d)
df
# Out:
#         Name  Age  Score
# 0      Alisa   36     85
# 1      Bobby   24     63
# 2      jodha   23     55
# 3       jack   22     74
# 4      raghu   23     31
# 5   Cathrine   24     77
# 6      Alisa   26     85
# 7      Bobby   24     63
# 8      kumar   22     42
# 9      Alisa   23     62
# 10      Alex   24     89
# 11  Cathrine   24     77

# %%
# drop duplicate rows

df.drop_duplicates()   # need to run again dataframe
# Out:
#         Name  Age  Score
# 0      Alisa   36     85
# 1      Bobby   24     63
# 2      jodha   23     55
# 3       jack   22     74
# 4      raghu   23     31
# 5   Cathrine   24     77
# 6      Alisa   26     85
# 8      kumar   22     42
# 9      Alisa   23     62
# 10      Alex   24     89

# %% [markdown]
# #  Drop the duplicate by retaining last occurrence

# %%
# drop duplicate rows

df.drop_duplicates(keep='last')
# Out:
#         Name  Age  Score
# 0      Alisa   36     85
# 2      jodha   23     55
# 3       jack   22     74
# 4      raghu   23     31
# 6      Alisa   26     85
# 7      Bobby   24     63
# 8      kumar   22     42
# 9      Alisa   23     62
# 10      Alex   24     89
# 11  Cathrine   24     77

# %% [markdown]
# #  Drop the duplicate by column:

# %%
import numpy as np

# Create a DataFrame
d = {
    'Name': ['Alisa', 'Bobby', 'jodha', 'jack', 'raghu',
             'Cathrine', 'Alisa', 'Bobby', 'kumar', 'Alisa', 
             'Alex', 'Cathrine'],
    'Customer_id': [26,24,23,22,23,24,26,24,22,23,24,24],
    'Score' : [85,63,55,74,31,77,85,63,42,62,89,77]
    }

df = pd.DataFrame(d)
df
# Out:
#         Name  Customer_id  Score
# 0      Alisa           26     85
# 1      Bobby           24     63
# 2      jodha           23     55
# 3       jack           22     74
# 4      raghu           23     31
# 5   Cathrine           24     77
# 6      Alisa           26     85
# 7      Bobby           24     63
# 8      kumar           22     42
# 9      Alisa           23     62
# 10      Alex           24     89
# 11  Cathrine           24     77

# %%
df.drop_duplicates(['Customer_id'])
# Out:
#     Name  Customer_id  Score
# 0  Alisa           26     85
# 1  Bobby           24     63
# 2  jodha           23     55
# 3   jack           22     74

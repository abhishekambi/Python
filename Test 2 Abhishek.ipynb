# %%
import pandas as pd

# %%
A = pd.read_excel(r'C:\Users\Abhishek\Desktop\Python\Global_Superstore.xlsx', sheet_name='Orders')
A
# Out:
#        Row ID                  Order_ID Order Date  Ship Date       Ship Mode  \
# 0       40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 1       26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07    Second Class
# 2       25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18     First Class
# 3       13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30     First Class
# 4       47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06        Same Day
# ...       ...                       ...        ...        ...             ...
# 51285   29002   IN-2015-KE1642066-42174 2015-06-19 2015-06-19        Same Day
# 51286   34337  US-2014-ZD21925140-41765 2014-05-06 2014-05-10  Standard Class
# 51287   31315  CA-2012-ZD21925140-41147 2012-08-26 2012-08-31    Second Class
# 51288    9596   MX-2013-RB1979518-41322 2013-02-17 2013-02-21  Standard Class
# 51289    6147   MX-2013-MC1810093-41416 2013-05-22 2013-05-26    Second Class
#
# ...

# %%
B = pd.read_excel(r'C:\Users\Abhishek\Desktop\Python\Global_Superstore.xlsx', sheet_name='Return')
B
# Out:
#                       Order_ID Returned           Region
# 0     CA-2012-SA20830140-41210      Yes       Central US
# 1     IN-2012-PB19210127-41259      Yes     Eastern Asia
# 2     CA-2012-SC20095140-41174      Yes       Central US
# 3       IN-2015-JH158207-42140      Yes          Oceania
# 4       IN-2014-LC168857-41747      Yes          Oceania
# ...                        ...      ...              ...
# 1074   IN-2014-DA1345058-41769      Yes    Southern Asia
# 1075  US-2013-HG14845140-41530      Yes       Eastern US
# 1076   US-2013-SJ2021582-41543      Yes  Central America
# 1077  CA-2015-EB13870140-42269      Yes       Eastern US
# 1078    EG-2014-PM894038-41846      Yes     North Africa
#
# [1079 rows x 3 columns]

# %%
Final_data = pd.merge (A, B, on ='Order_ID', how = 'outer')
Final_data
# Out:
#        Row ID                  Order_ID Order Date  Ship Date       Ship Mode  \
# 0       40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 1       40099  CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 2       26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07    Second Class
# 3       26339    IN-2014-JR162107-41675 2014-02-05 2014-02-07    Second Class
# 4       26340    IN-2014-JR162107-41675 2014-02-05 2014-02-07    Second Class
# ...       ...                       ...        ...        ...             ...
# 51285    6039   MX-2015-HG1502518-42164 2015-06-09 2015-06-11     First Class
# 51286   24175    IN-2015-DB132707-42221 2015-08-05 2015-08-10  Standard Class
# 51287   24105   IN-2015-KH1633058-42154 2015-05-30 2015-05-30        Same Day
# 51288   34337  US-2014-ZD21925140-41765 2014-05-06 2014-05-10  Standard Class
# 51289    6147   MX-2013-MC1810093-41416 2013-05-22 2013-05-26    Second Class
#
# ...

# %%
Final_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51290 entries, 0 to 51289
# Data columns (total 26 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          51290 non-null  int64
#  1   Order_ID        51290 non-null  object
#  2   Order Date      51290 non-null  datetime64[ns]
#  3   Ship Date       51290 non-null  datetime64[ns]
#  4   Ship Mode       51290 non-null  object
#  5   Customer ID     51290 non-null  object
#  6   Customer Name   51290 non-null  object
#  7   Segment         51290 non-null  object
#  8   Postal Code     9994 non-null   float64
#  9   City            51290 non-null  object
#  10  State           51290 non-null  object
#  11  Country         51290 non-null  object
#  12  Region_x        51290 non-null  object
#  13  Market          51290 non-null  object
#  14  Product_ID      51290 non-null  object
#  15  Category        51290 non-null  object
# ...

# %%
Final_data[['Category']]
# Out:
#               Category
# 0           Technology
# 1            Furniture
# 2            Furniture
# 3           Technology
# 4      Office Supplies
# ...                ...
# 51285  Office Supplies
# 51286  Office Supplies
# 51287  Office Supplies
# 51288        Furniture
# 51289  Office Supplies
#
# [51290 rows x 1 columns]

# %%
C = Final_data.loc[Final_data.Category=='Technology', Final_data.Sub_Category == 'Phones']
C
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 C = Final_data.loc[Final_data.Category=='Technology', Final_data.Sub_Category == 'Phones']
#       2 C
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:961, in _LocationIndexer.__getitem__(self, key)
#     959     if self._is_scalar_access(key):
#     960         return self.obj._get_value(*key, takeable=self._takeable)
# --> 961     return self._getitem_tuple(key)
#     962 else:
#     963     # we by definition only have the 0th axis
#     964     axis = self.axis or 0
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:1149, in _LocIndexer._getitem_tuple(self, tup)
#    1146 if self._multi_take_opportunity(tup):
#    1147     return self._multi_take(tup)
# -> 1149 return self._getitem_tuple_same_dim(tup)
#
# ...

# %%
D = Final_data.loc[Final_data.Profit > 0]
D
# Out:
#        Row ID                  Order_ID Order Date  Ship Date       Ship Mode  \
# 0       40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 1       40099  CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 3       26339    IN-2014-JR162107-41675 2014-02-05 2014-02-07    Second Class
# 5       26342    IN-2014-JR162107-41675 2014-02-05 2014-02-07    Second Class
# 6       25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18     First Class
# ...       ...                       ...        ...        ...             ...
# 51285    6039   MX-2015-HG1502518-42164 2015-06-09 2015-06-11     First Class
# 51286   24175    IN-2015-DB132707-42221 2015-08-05 2015-08-10  Standard Class
# 51287   24105   IN-2015-KH1633058-42154 2015-05-30 2015-05-30        Same Day
# 51288   34337  US-2014-ZD21925140-41765 2014-05-06 2014-05-10  Standard Class
# 51289    6147   MX-2013-MC1810093-41416 2013-05-22 2013-05-26    Second Class
#
# ...

# %%
E = Final_data.drop_duplicates("Order_ID") 
E
# Out:
#        Row ID                  Order_ID Order Date  Ship Date       Ship Mode  \
# 0       40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 2       26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07    Second Class
# 6       25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18     First Class
# 11      13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30     First Class
# 12      47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06        Same Day
# ...       ...                       ...        ...        ...             ...
# 51285    6039   MX-2015-HG1502518-42164 2015-06-09 2015-06-11     First Class
# 51286   24175    IN-2015-DB132707-42221 2015-08-05 2015-08-10  Standard Class
# 51287   24105   IN-2015-KH1633058-42154 2015-05-30 2015-05-30        Same Day
# 51288   34337  US-2014-ZD21925140-41765 2014-05-06 2014-05-10  Standard Class
# 51289    6147   MX-2013-MC1810093-41416 2013-05-22 2013-05-26    Second Class
#
# ...

# %%
F = Final_data.drop("Sales", axis = 1)
F
# Out:
#        Row ID                  Order_ID Order Date  Ship Date       Ship Mode  \
# 0       40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 1       40099  CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 2       26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07    Second Class
# 3       26339    IN-2014-JR162107-41675 2014-02-05 2014-02-07    Second Class
# 4       26340    IN-2014-JR162107-41675 2014-02-05 2014-02-07    Second Class
# ...       ...                       ...        ...        ...             ...
# 51285    6039   MX-2015-HG1502518-42164 2015-06-09 2015-06-11     First Class
# 51286   24175    IN-2015-DB132707-42221 2015-08-05 2015-08-10  Standard Class
# 51287   24105   IN-2015-KH1633058-42154 2015-05-30 2015-05-30        Same Day
# 51288   34337  US-2014-ZD21925140-41765 2014-05-06 2014-05-10  Standard Class
# 51289    6147   MX-2013-MC1810093-41416 2013-05-22 2013-05-26    Second Class
#
# ...

# %%
G = Final_data.drop(0,axis=0)
G
# Out:
#        Row ID                  Order_ID Order Date  Ship Date       Ship Mode  \
# 1       40099  CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 2       26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07    Second Class
# 3       26339    IN-2014-JR162107-41675 2014-02-05 2014-02-07    Second Class
# 4       26340    IN-2014-JR162107-41675 2014-02-05 2014-02-07    Second Class
# 5       26342    IN-2014-JR162107-41675 2014-02-05 2014-02-07    Second Class
# ...       ...                       ...        ...        ...             ...
# 51285    6039   MX-2015-HG1502518-42164 2015-06-09 2015-06-11     First Class
# 51286   24175    IN-2015-DB132707-42221 2015-08-05 2015-08-10  Standard Class
# 51287   24105   IN-2015-KH1633058-42154 2015-05-30 2015-05-30        Same Day
# 51288   34337  US-2014-ZD21925140-41765 2014-05-06 2014-05-10  Standard Class
# 51289    6147   MX-2013-MC1810093-41416 2013-05-22 2013-05-26    Second Class
#
# ...
